# %%
import pandas as pd
import re
import requests

# %%
data = pd.read_csv('Resources/90to18.csv')

# %%
data
# Out:
#       Unnamed: 0  Adult                                      Genres      Id  \
# 0              1  False          ['Adventure', 'Fantasy', 'Family']    8844
# 1              3  False              ['Comedy', 'Drama', 'Romance']   31357
# 2              5  False    ['Action', 'Crime', 'Drama', 'Thriller']     949
# 3              6  False                       ['Comedy', 'Romance']   11860
# 4              8  False         ['Action', 'Adventure', 'Thriller']    9091
# ...          ...    ...                                         ...     ...
# 2183        4589  False                      ['Action', 'Thriller']   56491
# 2184        4592  False                     ['Action', 'Adventure']  258489
# 2185        4610  False                                  ['Horror']   14564
# 2186        4619  False                        ['Drama', 'Romance']   14395
# 2187        4626  False  ['Action', 'Drama', 'Romance', 'Thriller']    8453
#
#         Imdb Id                                           Keywords  \
# 0     tt0113497  ['giant insect', 'board game', 'jungle', 'disa...
# 1     tt0114885  ['based on novel or book', 'interracial relati...
# 2     tt0113277  ['robbery', 'detective', 'bank', 'obsession', ...
# 3     tt0114319  ['paris, france', 'sibling relationship', 'cha...
# 4     tt0114576  ['terrorist', 'hostage', 'explosive', 'ice hoc...
# ...         ...                                                ...
# 2183  tt0487156  ['rebel', 'usa president', 'hostage', 'airplan...
# 2184  tt0918940  ['africa', 'animal attack', 'feral child', 'ta...
# 2185  tt0498381  ['hallucination', 'investigation', 'drama', 's...
# 2186  tt0449999                ['adultery', 'extramarital affair']
# 2187  tt0439662  ['blindness and impaired vision', 'new delhi i...
#
#                                    Production Companies  \
# 0     ['TriStar Pictures', 'Teitler Film', 'Intersco...
# 1            ['Twentieth Century Fox Film Corporation']
# 2     ['Regency Enterprises', 'Forward Pass', 'Warne...
# 3     ['Paramount Pictures', 'Scott Rudin Production...
# 4     ['Universal Pictures', 'Imperial Entertainment...
# ...                                                 ...
# 2183                                                 []
# 2184  ['Village Roadshow Pictures', 'Dark Horse Ente...
# 2185  ['Paramount Pictures', 'Vertigo Entertainment'...
# 2186           ['Yash Raj Films', 'Dharma Productions']
# 2187                                 ['Yash Raj Films']
#
#                                    Production Countries Release Date  Year  \
# 0                          ['United States of America']   12/15/1995  1995
# 1                          ['United States of America']   12/22/1995  1995
# 2                          ['United States of America']   12/15/1995  1995
# 3               ['Germany', 'United States of America']   12/15/1995  1995
# 4                          ['United States of America']   12/22/1995  1995
# ...                                                 ...          ...   ...
# 2183                       ['United States of America']    4/21/2006  2006
# 2184  ['Canada', 'United Kingdom', 'United States of...    6/29/2016  2016
# 2185                       ['United States of America']     2/1/2017  2017
# 2186                                          ['India']    8/11/2006  2006
# 2187                                          ['India']    5/26/2006  2006
#
#       ...                   Title     Budget  Popularity  Runtime  \
# 0     ...                 Jumanji   65000000   17.015539    104.0
# 1     ...       Waiting to Exhale   16000000    3.859495    127.0
# 2     ...                    Heat   60000000   17.924927    170.0
# 3     ...                 Sabrina   58000000    6.677277    127.0
# 4     ...            Sudden Death   35000000    5.231580    106.0
# ...   ...                     ...        ...         ...      ...
# 2183  ...     In Her Line of Fire    1000000    0.632334     88.0
# 2184  ...    The Legend of Tarzan  180000000   45.382980    109.0
# 2185  ...                   Rings   25000000   24.535733    102.0
# 2186  ...  Kabhi Alvida Naa Kehna    7400000    2.372520    193.0
# 2187  ...                   Fanaa    5300000    3.003526    168.0
#
#       Vote Average  Vote Count  \
# 0              6.9      2413.0
# 1              6.1        34.0
# 2              7.7      1886.0
# 3              6.2       141.0
# 4              5.5       174.0
# ...            ...         ...
# 2183           3.3         9.0
# 2184           5.5      2488.0
# 2185           4.8      1075.0
# 2186           6.1        45.0
# 2187           6.7        53.0
#
#                                                 New Key  Worldwide  \
# 0     ['board game', 'disappearance', 'new home', 'r...  262797249
# 1     ['based on novel', 'interracial relationship',...   81452156
# 2     ['robbery', 'detective', 'bank', 'obsession', ...  187436818
# 3     ['paris', 'brother brother relationship', 'cha...   53696278
# 4                 ['terrorist', 'hostage', 'explosive']   64350171
# ...                                                 ...        ...
# 2183  ['rebel', 'usa president', 'hostage', 'airplan...        884
# 2184      ['africa', 'feral child', 'tarzan', 'jungle']  356700357
# 2185  ['hallucination', 'investigation', 'drama', 's...   83080890
# 2186                                       ['adultery']   25229168
# 2187  ['blindness and impaired vision', 'new delhi i...   22175908
#
#          Domestic      Foreign
# 0     100475249.0  162322000.0
# 1      67052156.0   14400000.0
# 2      67436818.0  120000000.0
# 3      53672080.0      24198.0
# 4      20350171.0   44000000.0
# ...           ...          ...
# 2183        884.0          NaN
# 2184  126643061.0  230057296.0
# 2185   27793018.0   55287872.0
# 2186    3275444.0   21953724.0
# 2187    2105352.0   20070556.0
#
# [2188 rows x 21 columns]

# %%
one= data['Production Countries'][0]
test = re.findall(r"\[*{'iso_3166_1':\s'\w+',\s'name':\s'([\w\s]+)'},*",one)
test
# data['Keywords'].value_counts()
# Out:
# ['United States of America']

# %%
# one=data['Production Companies'][2]
# re.findall(r"\[*{'name':\s'([\w\s.]+)',\s'id':\s\w+},*",one)
# data['Worldwide']= data['Worldwide'].apply(lambda x: ''.join(re.findall(r'\$*(\d+),*',x)))
# data.head()

# %%
data = data.drop(columns = ['Unnamed: 0', 'Overview', 'Revenue'])
data = data.dropna()
# data['Keywords']= data['Keywords'].apply(lambda x: re.findall(r"\[*{'id':\s\w+,\s'name':\s'([\w\s]+)'},*",x))
data['Genres']= data['Genres'].apply(lambda x: re.findall(r"\[*{'id':\s\w+,\s'name':\s'([\w\s]+)'},*",x))
data['Production Companies']= data['Production Companies'].apply(lambda x: re.findall(r"\[*{'name':\s'([\w\s.]+)',\s'id':\s\w+},*",x))
data['Production Countries']= data['Production Countries'].apply(lambda x: re.findall(r"\[*{'iso_3166_1':\s'\w+',\s'name':\s'([\w\s]+)'},*",x))
data['Worldwide']= data['Worldwide'].apply(lambda x: ''.join(re.findall(r'\$*(\d+),*',x)))
data['Foreign']= data['Foreign'].apply(lambda x: ''.join(re.findall(r'\$*(\d+),*',x)))
data['Domestic']= data['Domestic'].apply(lambda x: ''.join(re.findall(r'\$*(\d+),*',x)))

# %%
data = data.drop(data.loc[(data['New Key']=='[]') | (data['Budget'] == 0) | (data['Genres']=='[]') | (data['Production Companies']=='[]')].index)
data.to_csv('Resources/90to18.csv')

# %%
# data.loc[(data['Budget'] == 0) | (data['Revenue'] == 0)][['Title','Imdb Id']]

# %%
madedprofit = []
percprofit = []
for index,row in data[['Budget','Worldwide']].iterrows():
    binary  = 1 if row[1]-row[0]>0 else 0
    make = 1 if row[1]/row[0]>1.10 else 0
    madedprofit.append(binary)
    percprofit.append(make)
#     break
data['Maded_Profit'] = madedprofit
data['Percent_Profit'] = percprofit
# make
data.head()
# Out:
#    Unnamed: 0  Adult                                    Genres     Id  \
# 0           1  False        ['Adventure', 'Fantasy', 'Family']   8844
# 1           3  False            ['Comedy', 'Drama', 'Romance']  31357
# 2           5  False  ['Action', 'Crime', 'Drama', 'Thriller']    949
# 3           6  False                     ['Comedy', 'Romance']  11860
# 4           8  False       ['Action', 'Adventure', 'Thriller']   9091
#
#      Imdb Id                                           Keywords  \
# 0  tt0113497  ['giant insect', 'board game', 'jungle', 'disa...
# 1  tt0114885  ['based on novel or book', 'interracial relati...
# 2  tt0113277  ['robbery', 'detective', 'bank', 'obsession', ...
# 3  tt0114319  ['paris, france', 'sibling relationship', 'cha...
# 4  tt0114576  ['terrorist', 'hostage', 'explosive', 'ice hoc...
#
#                                 Production Companies  \
# 0  ['TriStar Pictures', 'Teitler Film', 'Intersco...
# 1         ['Twentieth Century Fox Film Corporation']
# 2  ['Regency Enterprises', 'Forward Pass', 'Warne...
# 3  ['Paramount Pictures', 'Scott Rudin Production...
# 4  ['Universal Pictures', 'Imperial Entertainment...
#
#                       Production Countries Release Date  Year  ... Popularity  \
# 0             ['United States of America']   12/15/1995  1995  ...  17.015539
# 1             ['United States of America']   12/22/1995  1995  ...   3.859495
# 2             ['United States of America']   12/15/1995  1995  ...  17.924927
# 3  ['Germany', 'United States of America']   12/15/1995  1995  ...   6.677277
# 4             ['United States of America']   12/22/1995  1995  ...   5.231580
#
#   Runtime  Vote Average  Vote Count  \
# 0   104.0           6.9      2413.0
# 1   127.0           6.1        34.0
# 2   170.0           7.7      1886.0
# 3   127.0           6.2       141.0
# 4   106.0           5.5       174.0
#
#                                              New Key  Worldwide     Domestic  \
# 0  ['board game', 'disappearance', 'new home', 'r...  262797249  100475249.0
# 1  ['based on novel', 'interracial relationship',...   81452156   67052156.0
# 2  ['robbery', 'detective', 'bank', 'obsession', ...  187436818   67436818.0
# 3  ['paris', 'brother brother relationship', 'cha...   53696278   53672080.0
# 4              ['terrorist', 'hostage', 'explosive']   64350171   20350171.0
#
#        Foreign  Maded_Profit  Percent_Profit
# 0  162322000.0             1               1
# 1   14400000.0             1               1
# 2  120000000.0             1               1
# 3      24198.0             0               0
# 4   44000000.0             1               1
#
# [5 rows x 23 columns]

# %%
rev_df = pd.read_html(f'https://www.boxofficemojo.com/year/world/{2000+1}/')[0]
rev_df['Year']='2000'
for x in range(20):
    print(x+1)
    temp = pd.read_html(f'https://www.boxofficemojo.com/year/world/{2000+x+1}/')[0]
    temp['Year'] = f'{2000+x+1}'
    rev_df = pd.concat([rev_df,temp],ignore_index = True)
final_rev_df = rev_df.drop(columns = ['%','%.1','Rank'])
# Out:
# 1

# %%
# rev_df = pd.concat([rev_df,temp],ignore_index = True)
rev_df.drop(columns = ['%','%.1','Rank'])
# Out:
#                                          Release Group     Worldwide  \
# 0                Harry Potter and the Sorcerer's Stone  $974,755,371
# 1    The Lord of the Rings: The Fellowship of the Ring  $883,726,270
# 2                                       Monsters, Inc.  $528,773,250
# 3                                                Shrek  $484,409,218
# 4                                       Ocean's Eleven  $450,717,150
# ..                                                 ...           ...
# 803                                       Ginger Snaps        $2,554
# 804                 Whatever Happened to Harold Smith?        $2,543
# 805                               Love, Honor and Obey        $1,400
# 806                      The Last Wave 2001 Re-release          $957
# 807                            Sorority Girls' Revenge          $582
#
#          Domestic       Foreign  Year  year
# 0    $317,575,550  $657,179,821  2000   NaN
# 1    $313,364,114  $570,362,156  2000   NaN
# 2    $255,873,250  $272,900,000  2000   NaN
# 3    $267,665,011  $216,744,207  2000   NaN
# 4    $183,417,150  $267,300,000  2000   NaN
# ..            ...           ...   ...   ...
# 803        $2,554             -   NaN  2001
# 804        $2,543             -   NaN  2001
# 805        $1,400             -   NaN  2001
# 806          $957             -   NaN  2001
# 807          $582             -   NaN  2001
#
# [808 rows x 6 columns]
