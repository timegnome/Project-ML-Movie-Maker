# %%
import pandas as pd
import re
import requests

# %%
data = pd.read_csv('Resources/94to18.csv')

# %%
data
# Out:
#       Unnamed: 0  Adult                                             Genres  \
# 0              0  False  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1              1  False  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2              2  False  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3              3  False  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4              4  False                     [{'id': 35, 'name': 'Comedy'}]
# ...          ...    ...                                                ...
# 4625        4625  False                [{'id': 99, 'name': 'Documentary'}]
# 4626        4626  False  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 4627        4627  False  [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...
# 4628        4628  False                   [{'id': 53, 'name': 'Thriller'}]
# 4629        4629  False                                                 []
#
#           Id    Imdb Id                                           Keywords  \
# 0        862  tt0114709  ['jealousy', 'toy', 'boy', 'friendship', 'frie...
# 1       8844  tt0113497  ['giant insect', 'board game', 'jungle', 'disa...
# 2      15602  tt0113228  ['fishing', 'old man', 'best friend', 'duringc...
# 3      31357  tt0114885  ['based on novel or book', 'interracial relati...
# 4      11862  tt0113041  ['baby', 'midlife crisis', 'confidence', 'agin...
# ...      ...        ...                                                ...
# 4625   18221  tt0290296  ['nasa', 'space', 'independent film', 'astrona...
# 4626    8453  tt0439662  ['blindness and impaired vision', 'new delhi i...
# 4627  116753  tt0396962                                                 []
# 4628  298695  tt0813991                                                 []
# 4629   41811  tt0099480                                                 []
#
#                                                Overview  \
# 0     Led by Woody, Andy's toys live happily in his ...
# 1     When siblings Judy and Peter discover an encha...
# 2     A family wedding reignites the ancient feud be...
# 3     Cheated on, mistreated and stepped on, the wom...
# 4     Just when George Banks has recovered from his ...
# ...                                                 ...
# 4625  Some 220 miles above Earth lies the Internatio...
# 4626  Zooni Ali Beg (Kajol) is a blind Kashmiri girl...
# 4627  This story is about how an old man tried to sh...
# 4628  When a heart surgeon chooses to save one femal...
# 4629  At a spacious house in Los Angeles, Helene is ...
#
#                                    Production Companies  \
# 0        [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1     [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2     [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3     [{'name': 'Twentieth Century Fox Film Corporat...
# 4     [{'name': 'Sandollar Productions', 'id': 5842}...
# ...                                                 ...
# 4625  [{'name': 'IMAX', 'id': 3447}, {'name': 'Natio...
# 4626           [{'name': 'Yash Raj Films', 'id': 1569}]
# 4627                                                 []
# 4628  [{'name': 'Giant Films', 'id': 12319}, {'name'...
# 4629                                                 []
#
#                                    Production Countries Release Date  ...  \
# 0     [{'iso_3166_1': 'US', 'name': 'United States o...   10/30/1995  ...
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...   12/15/1995  ...
# 2     [{'iso_3166_1': 'US', 'name': 'United States o...   12/22/1995  ...
# 3     [{'iso_3166_1': 'US', 'name': 'United States o...   12/22/1995  ...
# 4     [{'iso_3166_1': 'US', 'name': 'United States o...    2/10/1995  ...
# ...                                                 ...          ...  ...
# 4625  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...    4/17/2002  ...
# 4626            [{'iso_3166_1': 'IN', 'name': 'India'}]    5/26/2006  ...
# 4627            [{'iso_3166_1': 'IN', 'name': 'India'}]   12/10/2004  ...
# 4628   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]     1/1/2009  ...
# 4629  [{'iso_3166_1': 'US', 'name': 'United States o...   11/30/1990  ...
#
#         Budget Popularity      Revenue  Runtime  Vote Average  Vote Count  \
# 0     30000000  21.946943  373554033.0     81.0           7.7      5415.0
# 1     65000000  17.015539  262797249.0    104.0           6.9      2413.0
# 2            0  11.712900          0.0    101.0           6.5        92.0
# 3     16000000   3.859495   81452156.0    127.0           6.1        34.0
# 4            0   8.387519   76578911.0    106.0           5.7       173.0
# ...        ...        ...          ...      ...           ...         ...
# 4625         0   3.071463          0.0     47.0           6.1        11.0
# 4626   5300000   3.003526   22175908.0    168.0           6.7        53.0
# 4627         0   0.356645          0.0    107.0           8.0         2.0
# 4628         0   0.077309          0.0     68.0           4.8         2.0
# 4629         0   0.000002          0.0    110.0           0.0         0.0
#
#                                                 New Key     Worldwide  \
# 0     ['jealousy', 'toy', 'boy', 'friendship', 'frie...  $363,007,140
# 1     ['board game', 'disappearance', 'new home', 'r...  $262,797,249
# 2     ['fishing', 'best friend', 'duringcreditssting...   $71,518,503
# 3     ['based on novel', 'interracial relationship',...   $81,452,156
# 4     ['baby', 'midlife crisis', 'confidence', 'agin...   $76,594,107
# ...                                                 ...           ...
# 4625  ['nasa', 'space', 'independent film', 'astrona...  $128,363,881
# 4626  ['blindness and impaired vision', 'new delhi i...   $22,175,908
# 4627                                                 []        $1,416
# 4628                                                 []        $9,955
# 4629                                                 []    $2,100,538
#
#           Domestic       Foreign
# 0     $191,796,233  $171,210,907
# 1     $100,475,249  $162,322,000
# 2      $71,518,503             -
# 3      $67,052,156   $14,400,000
# 4      $76,594,107             -
# ...            ...           ...
# 4625   $93,383,953   $34,979,928
# 4626    $2,105,352   $20,070,556
# 4627        $1,416             -
# 4628        $9,955             -
# 4629    $2,100,538             -
#
# [4630 rows x 23 columns]

# %%
one= data['Production Countries'][0]
test = re.findall(r"\[*{'iso_3166_1':\s'\w+',\s'name':\s'([\w\s]+)'},*",one)
test
# data['Keywords'].value_counts()
# Out:
# ['United States of America']

# %%
# one=data['Production Companies'][2]
# re.findall(r"\[*{'name':\s'([\w\s.]+)',\s'id':\s\w+},*",one)
# data['Worldwide']= data['Worldwide'].apply(lambda x: ''.join(re.findall(r'\$*(\d+),*',x)))
# data.head()

# %%
data = data.drop(columns = ['Unnamed: 0', 'Overview', 'Revenue'])
data = data.dropna()
# data['Keywords']= data['Keywords'].apply(lambda x: re.findall(r"\[*{'id':\s\w+,\s'name':\s'([\w\s]+)'},*",x))
data['Genres']= data['Genres'].apply(lambda x: re.findall(r"\[*{'id':\s\w+,\s'name':\s'([\w\s]+)'},*",x))
data['Production Companies']= data['Production Companies'].apply(lambda x: re.findall(r"\[*{'name':\s'([\w\s.]+)',\s'id':\s\w+},*",x))
data['Production Countries']= data['Production Countries'].apply(lambda x: re.findall(r"\[*{'iso_3166_1':\s'\w+',\s'name':\s'([\w\s]+)'},*",x))
data['Worldwide']= data['Worldwide'].apply(lambda x: ''.join(re.findall(r'\$*(\d+),*',x)))
data['Foreign']= data['Foreign'].apply(lambda x: ''.join(re.findall(r'\$*(\d+),*',x)))
data['Domestic']= data['Domestic'].apply(lambda x: ''.join(re.findall(r'\$*(\d+),*',x)))

# %%
data = data.drop(data.loc[(data['New Key']=='[]') | (data['Budget'] == 0) | (data['Genres']=='[]') | (data['Production Companies']=='[]')].index)
data.to_csv('90to18')

# %%
data.loc[(data['Budget'] == 0) | (data['Revenue'] == 0)][['Title','Imdb Id']]
# Out:
#                              Title    Imdb Id
# 2                 Grumpier Old Men  tt0113228
# 4      Father of the Bride Part II  tt0113041
# 6                          Sabrina  tt0114319
# 7                     Tom and Huck  tt0112302
# 11     Dracula: Dead and Loving It  tt0112896
# ...                            ...        ...
# 30516          The Burkittsville 7  tt0252966
# 30517              Caged Heat 3000  tt0112613
# 30518                   Robin Hood  tt0102797
# 30519                     Betrayal  tt0303758
# 30520             Satan Triumphant  tt0008536
#
# [26857 rows x 2 columns]

# %%
rev_df = pd.read_html(f'https://www.boxofficemojo.com/year/world/{2000+1}/')[0]
rev_df['Year']='2000'
for x in range(20):
    print(x+1)
    temp = pd.read_html(f'https://www.boxofficemojo.com/year/world/{2000+x+1}/')[0]
    temp['Year'] = f'{2000+x+1}'
    rev_df = pd.concat([rev_df,temp],ignore_index = True)
final_rev_df = rev_df.drop(columns = ['%','%.1','Rank'])
# Out:
# 1

# %%
# rev_df = pd.concat([rev_df,temp],ignore_index = True)
rev_df.drop(columns = ['%','%.1','Rank'])
# Out:
#                                          Release Group     Worldwide  \
# 0                Harry Potter and the Sorcerer's Stone  $974,755,371
# 1    The Lord of the Rings: The Fellowship of the Ring  $883,726,270
# 2                                       Monsters, Inc.  $528,773,250
# 3                                                Shrek  $484,409,218
# 4                                       Ocean's Eleven  $450,717,150
# ..                                                 ...           ...
# 803                                       Ginger Snaps        $2,554
# 804                 Whatever Happened to Harold Smith?        $2,543
# 805                               Love, Honor and Obey        $1,400
# 806                      The Last Wave 2001 Re-release          $957
# 807                            Sorority Girls' Revenge          $582
#
#          Domestic       Foreign  Year  year
# 0    $317,575,550  $657,179,821  2000   NaN
# 1    $313,364,114  $570,362,156  2000   NaN
# 2    $255,873,250  $272,900,000  2000   NaN
# 3    $267,665,011  $216,744,207  2000   NaN
# 4    $183,417,150  $267,300,000  2000   NaN
# ..            ...           ...   ...   ...
# 803        $2,554             -   NaN  2001
# 804        $2,543             -   NaN  2001
# 805        $1,400             -   NaN  2001
# 806          $957             -   NaN  2001
# 807          $582             -   NaN  2001
#
# [808 rows x 6 columns]
